# %%
import pandas as pd

# %%
actor_df=pd.read_csv('data/best_actor_winners_1928-2023.csv',encoding='utf-8')

# %%
actor_df.shape
# Out:
# (96, 6)

# %%
actor_df.tail()
# Out:
#            Year             Actor                Role(s)          Film  Age  \
# 91      2019 \n  Joaquin Phoenix    Arthur Fleck / Joker         Joker   45
# 92  2020/21\n\n  Anthony Hopkins                 Anthony    The Father   83
# 93       2021\n       Will Smith        Richard Williams  King Richard   53
# 94       2022\n   Brendan Fraser                 Charlie     The Whale   54
# 95       2023\n   Cillian Murphy   J. Robert Oppenheimer   Oppenheimer   47
#
#    Nationality
# 91    American
# 92     British
# 93    American
# 94    Canadian
# 95       Irish

# %%
actor_df.isnull().sum()
# Out:
# Year           0
# Actor          0
# Role(s)        0
# Film           0
# Age            0
# Nationality    0
# dtype: int64

# %%
actor_df.dtypes
# Out:
# Year           object
# Actor          object
# Role(s)        object
# Film           object
# Age             int64
# Nationality    object
# dtype: object

# %%
actor_df['Year'].unique()
# Out:
# array(['1928 \n', '1929\n', '1930 \n', '1931 \n', '1932 \n', '1933 \n',
#        '1934 \n', '1935 \n', '1936 \n', '1937 \n', '1938 \n', '1939 \n',
#        '1940 \n', '1941 \n', '1942 \n', '1943 \n', '1944 \n', '1945 \n',
#        '1946 \n', '1947 \n', '1948 \n', '1949 \n', '1950 \n', '1951 \n',
#        '1952 \n', '1953 \n', '1954 \n', '1955 \n', '1956 \n', '1957 \n',
#        '1958 \n', '1959 \n', '1960 \n', '1961 \n', '1962 \n', '1963 \n',
#        '1964 \n', '1965 \n', '1966 \n', '1967 \n', '1968 \n', '1969 \n',
#        '1970 \n', '1971 \n', '1972 \n', '1973 \n', '1974 \n', '1975 \n',
#        '1976 \n', '1977 \n', '1978 \n', '1979 \n', '1980 \n', '1981 \n',
#        '1982 \n', '1983 \n', '1984 \n', '1985 \n', '1986 \n', '1987 \n',
#        '1988 \n', '1989 \n', '1990 \n', '1991 \n', '1992 \n', '1993 \n',
#        '1994 \n', '1995 \n', '1996 \n', '1997 \n', '1998 \n', '1999 \n',
#        '2000 \n', '2001 \n', '2002 \n', '2003 \n', '2004 \n', '2005 \n',
#        '2006 \n', '2007 \n', '2008 \n', '2009 \n', '2010 \n', '2011 \n',
#        '2012 \n', '2013 \n', '2014 \n', '2015 \n', '2016 \n', '2017 \n',
#        '2018 \n', '2019 \n', '2020/21\n\n', '2021\n', '2022\n', '2023\n'],
#       dtype=object)

# %%
actor_df['Year'] =actor_df['Year'].str.strip()

# %%
actor_df['Year'] = actor_df['Year'].str.replace(r'\D', '', regex=True)

# %%
actor_df.head()
# Out:
#    Year              Actor                       Role(s)              Film  \
# 0  1928     Emil Jannings   Grand Duke Sergius Alexander  The Last Command
# 1  1929     Warner Baxter                  The Cisco Kid    In Old Arizona
# 2  1930     George Arliss              Benjamin Disraeli          Disraeli
# 3  1931  Lionel Barrymore                   Stephen Ashe       A Free Soul
# 4  1932     Wallace Beery           Andy "Champ" Purcell         The Champ
#
#    Age Nationality
# 0   44      German
# 1   39    American
# 2   61     British
# 3   53    American
# 4   48    American

# %%
oscars3_df=pd.read_csv('data/oscars3.csv')

# %%
oscars3_df.shape
# Out:
# (10889, 7)

# %%
oscars3_df.head(20)
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1927           1928         1                         ACTOR
# 1        1927           1928         1                         ACTOR
# 2        1927           1928         1                       ACTRESS
# 3        1927           1928         1                       ACTRESS
# 4        1927           1928         1                       ACTRESS
# 5        1927           1928         1                 ART DIRECTION
# 6        1927           1928         1                 ART DIRECTION
# 7        1927           1928         1                 ART DIRECTION
# 8        1927           1928         1                CINEMATOGRAPHY
# 9        1927           1928         1                CINEMATOGRAPHY
# 10       1927           1928         1                CINEMATOGRAPHY
# 11       1927           1928         1    DIRECTING (Comedy Picture)
# 12       1927           1928         1    DIRECTING (Comedy Picture)
# 13       1927           1928         1  DIRECTING (Dramatic Picture)
# 14       1927           1928         1  DIRECTING (Dramatic Picture)
# 15       1927           1928         1  DIRECTING (Dramatic Picture)
# 16       1927           1928         1           ENGINEERING EFFECTS
# 17       1927           1928         1           ENGINEERING EFFECTS
# 18       1927           1928         1           ENGINEERING EFFECTS
# 19       1927           1928         1           OUTSTANDING PICTURE
#
#                        name                 film  winner
# 0       Richard Barthelmess            The Noose   False
# 1             Emil Jannings     The Last Command    True
# 2            Louise Dresser      A Ship Comes In   False
# 3              Janet Gaynor           7th Heaven    True
# 4            Gloria Swanson       Sadie Thompson   False
# 5             Rochus Gliese              Sunrise   False
# 6   William Cameron Menzies            The Dove;    True
# 7              Harry Oliver           7th Heaven   False
# 8             George Barnes    The Devil Dancer;   False
# 9            Charles Rosher              Sunrise    True
# 10              Karl Struss              Sunrise    True
# 11          Lewis Milestone  Two Arabian Knights    True
# 12                Ted Wilde               Speedy   False
# 13            Frank Borzage           7th Heaven    True
# 14           Herbert Brenon      Sorrell and Son   False
# 15               King Vidor            The Crowd   False
# 16           Ralph Hammeras                  NaN   False
# 17              Roy Pomeroy                Wings    True
# 18         Nugent Slaughter                  NaN   False
# 19        The Caddo Company           The Racket   False

# %%
oscars3_df_1928=oscars3_df[oscars3_df['year_ceremony']==1928]

# %%
oscars3_df_1928
# Out:
#     year_film  year_ceremony  ceremony                      category  \
# 0        1927           1928         1                         ACTOR
# 1        1927           1928         1                         ACTOR
# 2        1927           1928         1                       ACTRESS
# 3        1927           1928         1                       ACTRESS
# 4        1927           1928         1                       ACTRESS
# 5        1927           1928         1                 ART DIRECTION
# 6        1927           1928         1                 ART DIRECTION
# 7        1927           1928         1                 ART DIRECTION
# 8        1927           1928         1                CINEMATOGRAPHY
# 9        1927           1928         1                CINEMATOGRAPHY
# 10       1927           1928         1                CINEMATOGRAPHY
# 11       1927           1928         1    DIRECTING (Comedy Picture)
# 12       1927           1928         1    DIRECTING (Comedy Picture)
# 13       1927           1928         1  DIRECTING (Dramatic Picture)
# 14       1927           1928         1  DIRECTING (Dramatic Picture)
# 15       1927           1928         1  DIRECTING (Dramatic Picture)
# 16       1927           1928         1           ENGINEERING EFFECTS
# 17       1927           1928         1           ENGINEERING EFFECTS
# 18       1927           1928         1           ENGINEERING EFFECTS
# 19       1927           1928         1           OUTSTANDING PICTURE
# 20       1927           1928         1           OUTSTANDING PICTURE
# 21       1927           1928         1           OUTSTANDING PICTURE
# 22       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 23       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 24       1927           1928         1   UNIQUE AND ARTISTIC PICTURE
# 25       1927           1928         1          WRITING (Adaptation)
# 26       1927           1928         1          WRITING (Adaptation)
# 27       1927           1928         1          WRITING (Adaptation)
# 28       1927           1928         1      WRITING (Original Story)
# 29       1927           1928         1      WRITING (Original Story)
# 30       1927           1928         1       WRITING (Title Writing)
# 31       1927           1928         1       WRITING (Title Writing)
# 32       1927           1928         1       WRITING (Title Writing)
# 33       1927           1928         1                 SPECIAL AWARD
# 34       1927           1928         1                 SPECIAL AWARD
#
#                        name                               film  winner
# 0       Richard Barthelmess                          The Noose   False
# 1             Emil Jannings                   The Last Command    True
# 2            Louise Dresser                    A Ship Comes In   False
# 3              Janet Gaynor                         7th Heaven    True
# 4            Gloria Swanson                     Sadie Thompson   False
# 5             Rochus Gliese                            Sunrise   False
# 6   William Cameron Menzies                          The Dove;    True
# 7              Harry Oliver                         7th Heaven   False
# 8             George Barnes                  The Devil Dancer;   False
# 9            Charles Rosher                            Sunrise    True
# 10              Karl Struss                            Sunrise    True
# 11          Lewis Milestone                Two Arabian Knights    True
# 12                Ted Wilde                             Speedy   False
# 13            Frank Borzage                         7th Heaven    True
# 14           Herbert Brenon                    Sorrell and Son   False
# 15               King Vidor                          The Crowd   False
# 16           Ralph Hammeras                                NaN   False
# 17              Roy Pomeroy                              Wings    True
# 18         Nugent Slaughter                                NaN   False
# 19        The Caddo Company                         The Racket   False
# 20                      Fox                         7th Heaven   False
# 21   Paramount Famous Lasky                              Wings    True
# 22                      Fox                            Sunrise    True
# 23      Metro-Goldwyn-Mayer                          The Crowd   False
# 24   Paramount Famous Lasky                              Chang   False
# 25              Alfred Cohn                    The Jazz Singer   False
# 26         Anthony Coldeway                     Glorious Betsy   False
# 27          Benjamin Glazer                         7th Heaven    True
# 28               Lajos Biro                   The Last Command   False
# 29                Ben Hecht                         Underworld    True
# 30             Gerald Duffy  The Private Life of Helen of Troy   False
# 31           Joseph Farnham                                NaN    True
# 32       George Marion, Jr.                                NaN   False
# 33             Warner Bros.                                NaN    True
# 34          Charles Chaplin                                NaN    True

# %%
oscars3_df['category'].unique
# Out:
# <bound method Series.unique of 0                                   ACTOR
# 1                                   ACTOR
# 2                                 ACTRESS
# 3                                 ACTRESS
# 4                                 ACTRESS
#                        ...
# 10884       WRITING (Original Screenplay)
# 10885    JEAN HERSHOLT HUMANITARIAN AWARD
# 10886                      HONORARY AWARD
# 10887                      HONORARY AWARD
# 10888                      HONORARY AWARD
# Name: category, Length: 10889, dtype: object>

# %%
oscars3_df2 = oscars3_df[oscars3_df['category'] == 'ACTOR']

# %%
oscars3_df2
# Out:
#       year_film  year_ceremony  ceremony category                 name  \
# 0          1927           1928         1    ACTOR  Richard Barthelmess
# 1          1927           1928         1    ACTOR        Emil Jannings
# 35         1928           1929         2    ACTOR      George Bancroft
# 36         1928           1929         2    ACTOR        Warner Baxter
# 37         1928           1929         2    ACTOR       Chester Morris
# ...         ...            ...       ...      ...                  ...
# 5298       1975           1976        48    ACTOR       Walter Matthau
# 5299       1975           1976        48    ACTOR       Jack Nicholson
# 5300       1975           1976        48    ACTOR            Al Pacino
# 5301       1975           1976        48    ACTOR    Maximilian Schell
# 5302       1975           1976        48    ACTOR       James Whitmore
#
#                                  film  winner
# 0                           The Noose   False
# 1                    The Last Command    True
# 35                        Thunderbolt   False
# 36                     In Old Arizona    True
# 37                              Alibi   False
# ...                               ...     ...
# 5298                The Sunshine Boys   False
# 5299  One Flew over the Cuckoo's Nest    True
# 5300                Dog Day Afternoon   False
# 5301       The Man in the Glass Booth   False
# 5302            Give 'em Hell, Harry!   False
#
# [232 rows x 7 columns]

# %%
oscars3_df2.reset_index(drop=True, inplace=True)

# %%
oscars3_df2
# Out:
#      year_film  year_ceremony  ceremony category                 name  \
# 0         1927           1928         1    ACTOR  Richard Barthelmess
# 1         1927           1928         1    ACTOR        Emil Jannings
# 2         1928           1929         2    ACTOR      George Bancroft
# 3         1928           1929         2    ACTOR        Warner Baxter
# 4         1928           1929         2    ACTOR       Chester Morris
# ..         ...            ...       ...      ...                  ...
# 227       1975           1976        48    ACTOR       Walter Matthau
# 228       1975           1976        48    ACTOR       Jack Nicholson
# 229       1975           1976        48    ACTOR            Al Pacino
# 230       1975           1976        48    ACTOR    Maximilian Schell
# 231       1975           1976        48    ACTOR       James Whitmore
#
#                                 film  winner
# 0                          The Noose   False
# 1                   The Last Command    True
# 2                        Thunderbolt   False
# 3                     In Old Arizona    True
# 4                              Alibi   False
# ..                               ...     ...
# 227                The Sunshine Boys   False
# 228  One Flew over the Cuckoo's Nest    True
# 229                Dog Day Afternoon   False
# 230       The Man in the Glass Booth   False
# 231            Give 'em Hell, Harry!   False
#
# [232 rows x 7 columns]

# %%
oscars3_df2.insert(loc=5, column="Edad", value=pd.NA)

# %%
oscars3_df2.insert(loc=6, column="Nacionalidad", value=pd.NA)

# %%
oscars3_df2.insert(loc=6, column="Raza", value=pd.NA)

# %%
oscars3_df2.head ()
# Out:
#    year_film  year_ceremony  ceremony category                 name  Edad  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess  <NA>
# 1       1927           1928         1    ACTOR        Emil Jannings  <NA>
# 2       1928           1929         2    ACTOR      George Bancroft  <NA>
# 3       1928           1929         2    ACTOR        Warner Baxter  <NA>
# 4       1928           1929         2    ACTOR       Chester Morris  <NA>
#
#    Raza Nacionalidad              film  winner
# 0  <NA>         <NA>         The Noose   False
# 1  <NA>         <NA>  The Last Command    True
# 2  <NA>         <NA>       Thunderbolt   False
# 3  <NA>         <NA>    In Old Arizona    True
# 4  <NA>         <NA>             Alibi   False

# %%
oscars3_df2.drop(columns=["ceremony"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 oscars3_df2.drop(columns=["ceremony"], inplace=True)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['ceremony'] not found in axis"

# %%
oscars3_df2
# Out:
#      year_film  year_ceremony category                 name  Edad  Raza  \
# 0         1927           1928    ACTOR  Richard Barthelmess  <NA>  <NA>
# 1         1927           1928    ACTOR        Emil Jannings  <NA>  <NA>
# 2         1928           1929    ACTOR      George Bancroft  <NA>  <NA>
# 3         1928           1929    ACTOR        Warner Baxter  <NA>  <NA>
# 4         1928           1929    ACTOR       Chester Morris  <NA>  <NA>
# ..         ...            ...      ...                  ...   ...   ...
# 227       1975           1976    ACTOR       Walter Matthau  <NA>  <NA>
# 228       1975           1976    ACTOR       Jack Nicholson  <NA>  <NA>
# 229       1975           1976    ACTOR            Al Pacino  <NA>  <NA>
# 230       1975           1976    ACTOR    Maximilian Schell  <NA>  <NA>
# 231       1975           1976    ACTOR       James Whitmore  <NA>  <NA>
#
#     Nacionalidad                             film  winner
# 0           <NA>                        The Noose   False
# 1           <NA>                 The Last Command    True
# 2           <NA>                      Thunderbolt   False
# 3           <NA>                   In Old Arizona    True
# 4           <NA>                            Alibi   False
# ..           ...                              ...     ...
# 227         <NA>                The Sunshine Boys   False
# 228         <NA>  One Flew over the Cuckoo's Nest    True
# 229         <NA>                Dog Day Afternoon   False
# 230         <NA>       The Man in the Glass Booth   False
# 231         <NA>            Give 'em Hell, Harry!   False
#
# [232 rows x 9 columns]

# %%
oscars3_df2.insert(loc=9, column="Taquilla", value=pd.NA)

# %%
oscars3_df2.shape
# Out:
# (232, 10)

# %%
directores= oscars3_df

# %%
directores['category'].nunique()
# Out:
# 115

# %%
# directores_filtrado = directores.loc[directores['winner'] == True, ['category'].str.contains('DIRECTING', case=False, na=False)]

directores_filtrado = directores.loc[(directores['winner'] == True) & (directores['category'].str.contains('DIRECTING', case=False, na=False))]

# %%
directores_filtrado1 = directores.loc[
    (directores['winner'] == True) & 
    (directores['category'].str.contains('DIRECTING', case=False, na=False))]

# %%
directores_filtrado1
# Out:
#        year_film  year_ceremony  ceremony                      category  \
# 11          1927           1928         1    DIRECTING (Comedy Picture)
# 13          1927           1928         1  DIRECTING (Dramatic Picture)
# 59          1928           1929         2                     DIRECTING
# 98          1929           1930         3                     DIRECTING
# 139         1930           1931         4                     DIRECTING
# ...          ...            ...       ...                           ...
# 10306       2019           2020        92                     DIRECTING
# 10433       2020           2021        93                     DIRECTING
# 10553       2021           2022        94                     DIRECTING
# 10675       2022           2023        95                     DIRECTING
# 10802       2023           2024        96                     DIRECTING
#
#                                    name                               film  \
# 11                      Lewis Milestone                Two Arabian Knights
# 13                        Frank Borzage                         7th Heaven
# 59                          Frank Lloyd                    The Divine Lady
# 98                      Lewis Milestone     All Quiet on the Western Front
# 139                       Norman Taurog                             Skippy
# ...                                 ...                                ...
# 10306                      Bong Joon Ho                           Parasite
# 10433                        Chloé Zhao                          Nomadland
# 10553                      Jane Campion               The Power of the Dog
# 10675  Daniel Kwan and Daniel Scheinert  Everything Everywhere All at Once
# 10802                 Christopher Nolan                        Oppenheimer
#
#        winner
# 11       True
# 13       True
# 59       True
# 98       True
# 139      True
# ...       ...
# 10306    True
# 10433    True
# 10553    True
# 10675    True
# 10802    True
#
# [97 rows x 7 columns]

# %%
directores_filtrado1.drop(columns=['year_film','ceremony',],inplace=True)
# Out:
# C:\Users\jesus\AppData\Local\Temp\ipykernel_18772\625187862.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directores_filtrado1.drop(columns=['year_film','ceremony',],inplace=True)

# %%
directores_filtrado1.reset_index(drop=True,inplace=True)

# %%
directores_filtrado
# Out:
#        year_film  year_ceremony  ceremony                      category  \
# 11          1927           1928         1    DIRECTING (Comedy Picture)
# 13          1927           1928         1  DIRECTING (Dramatic Picture)
# 59          1928           1929         2                     DIRECTING
# 98          1929           1930         3                     DIRECTING
# 139         1930           1931         4                     DIRECTING
# ...          ...            ...       ...                           ...
# 10306       2019           2020        92                     DIRECTING
# 10433       2020           2021        93                     DIRECTING
# 10553       2021           2022        94                     DIRECTING
# 10675       2022           2023        95                     DIRECTING
# 10802       2023           2024        96                     DIRECTING
#
#                                    name                               film  \
# 11                      Lewis Milestone                Two Arabian Knights
# 13                        Frank Borzage                         7th Heaven
# 59                          Frank Lloyd                    The Divine Lady
# 98                      Lewis Milestone     All Quiet on the Western Front
# 139                       Norman Taurog                             Skippy
# ...                                 ...                                ...
# 10306                      Bong Joon Ho                           Parasite
# 10433                        Chloé Zhao                          Nomadland
# 10553                      Jane Campion               The Power of the Dog
# 10675  Daniel Kwan and Daniel Scheinert  Everything Everywhere All at Once
# 10802                 Christopher Nolan                        Oppenheimer
#
#        winner
# 11       True
# 13       True
# 59       True
# 98       True
# 139      True
# ...       ...
# 10306    True
# 10433    True
# 10553    True
# 10675    True
# 10802    True
#
# [97 rows x 7 columns]

# %%
directores_filtrado['category'].unique ()
# Out:
# array(['DIRECTING (Comedy Picture)', 'DIRECTING (Dramatic Picture)',
#        'DIRECTING'], dtype=object)

# %%
directores_filtrado.loc[:,'category']='director'

# %%
directores_filtrado
# Out:
#        year_film  year_ceremony  ceremony  category  \
# 11          1927           1928         1  director
# 13          1927           1928         1  director
# 59          1928           1929         2  director
# 98          1929           1930         3  director
# 139         1930           1931         4  director
# ...          ...            ...       ...       ...
# 10306       2019           2020        92  director
# 10433       2020           2021        93  director
# 10553       2021           2022        94  director
# 10675       2022           2023        95  director
# 10802       2023           2024        96  director
#
#                                    name                               film  \
# 11                      Lewis Milestone                Two Arabian Knights
# 13                        Frank Borzage                         7th Heaven
# 59                          Frank Lloyd                    The Divine Lady
# 98                      Lewis Milestone     All Quiet on the Western Front
# 139                       Norman Taurog                             Skippy
# ...                                 ...                                ...
# 10306                      Bong Joon Ho                           Parasite
# 10433                        Chloé Zhao                          Nomadland
# 10553                      Jane Campion               The Power of the Dog
# 10675  Daniel Kwan and Daniel Scheinert  Everything Everywhere All at Once
# 10802                 Christopher Nolan                        Oppenheimer
#
#        winner
# 11       True
# 13       True
# 59       True
# 98       True
# 139      True
# ...       ...
# 10306    True
# 10433    True
# 10553    True
# 10675    True
# 10802    True
#
# [97 rows x 7 columns]

# %%
directores_filtrado1
# Out:
#     year_ceremony                      category  \
# 0            1928    DIRECTING (Comedy Picture)
# 1            1928  DIRECTING (Dramatic Picture)
# 2            1929                     DIRECTING
# 3            1930                     DIRECTING
# 4            1931                     DIRECTING
# ..            ...                           ...
# 92           2020                     DIRECTING
# 93           2021                     DIRECTING
# 94           2022                     DIRECTING
# 95           2023                     DIRECTING
# 96           2024                     DIRECTING
#
#                                 name                               film  \
# 0                    Lewis Milestone                Two Arabian Knights
# 1                      Frank Borzage                         7th Heaven
# 2                        Frank Lloyd                    The Divine Lady
# 3                    Lewis Milestone     All Quiet on the Western Front
# 4                      Norman Taurog                             Skippy
# ..                               ...                                ...
# 92                      Bong Joon Ho                           Parasite
# 93                        Chloé Zhao                          Nomadland
# 94                      Jane Campion               The Power of the Dog
# 95  Daniel Kwan and Daniel Scheinert  Everything Everywhere All at Once
# 96                 Christopher Nolan                        Oppenheimer
#
#     winner
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ..     ...
# 92    True
# 93    True
# 94    True
# 95    True
# 96    True
#
# [97 rows x 5 columns]

# %%
directores_filtrado1.loc[:, 'category'] = 'director'

# %%
directores_filtrado1
# Out:
#     year_ceremony  category                              name  \
# 0            1928  director                   Lewis Milestone
# 1            1928  director                     Frank Borzage
# 2            1929  director                       Frank Lloyd
# 3            1930  director                   Lewis Milestone
# 4            1931  director                     Norman Taurog
# ..            ...       ...                               ...
# 92           2020  director                      Bong Joon Ho
# 93           2021  director                        Chloé Zhao
# 94           2022  director                      Jane Campion
# 95           2023  director  Daniel Kwan and Daniel Scheinert
# 96           2024  director                 Christopher Nolan
#
#                                  film  winner
# 0                 Two Arabian Knights    True
# 1                          7th Heaven    True
# 2                     The Divine Lady    True
# 3      All Quiet on the Western Front    True
# 4                              Skippy    True
# ..                                ...     ...
# 92                           Parasite    True
# 93                          Nomadland    True
# 94               The Power of the Dog    True
# 95  Everything Everywhere All at Once    True
# 96                        Oppenheimer    True
#
# [97 rows x 5 columns]

# %%
directores_filtrado1.drop(columns='columna',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 directores_filtrado1.drop(columns='columna',inplace=True)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File c:\Users\jesus\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['columna'] not found in axis"

# %%
# Guardar en un archivo CSV el dataframe directores_filtrado1
directores_filtrado1.to_csv('data/processed/directores_filtrado.csv', index=False)
