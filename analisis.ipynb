# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/processed/oscars_main_2_con_caracteristicas_actores.csv')

df.head(10)
# Out:
#    year_ceremony               film  winner                 name  edad  \
# 0           1928          The Noose   False  Richard Barthelmess   NaN
# 1           1928   The Last Command    True        Emil Jannings  45.0
# 2           1929        Thunderbolt   False      George Bancroft   NaN
# 3           1929     In Old Arizona    True        Warner Baxter  40.0
# 4           1929              Alibi   False       Chester Morris   NaN
# 5           1929        The Valiant   False            Paul Muni  42.0
# 6           1929        The Patriot   False          Lewis Stone   NaN
# 7           1930           Disraeli    True        George Arliss   NaN
# 8           1930  The Green Goddess   False        George Arliss   NaN
# 9           1930      The Big House   False        Wallace Beery  51.0
#
#      raza    nacionalidad
# 0     NaN             NaN
# 1  Blanca        Alemania
# 2     NaN             NaN
# 3  Blanca  Estados Unidos
# 4     NaN             NaN
# ...

# %%
media_edad = df['edad'].mean()
print('Media de edad de los actores:', media_edad)
# Out:
# Media de edad de los actores: 42.129629629629626
